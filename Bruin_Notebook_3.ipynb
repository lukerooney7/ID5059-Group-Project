# %% [markdown]
# # ID5059 Group 4 Assignment

# %%
# Libraries Required for Project (Added as Project Progresses)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, SGDRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# ## 1. Display the first few Observations
# The first step will be to load the dataset
# The head() and sample() methods will be used to look at the features and observations of the dataset.

# %%
# Load the dataset from CSV
train_df = pd.read_csv('train.csv')

# Confirm it's loaded by showing the shape
print(f"Data loaded: {train_df.shape[0]:,} rows and {train_df.shape[1]} columns")

# Display the first few rows
train_df.head()

# Display a random five rows
train_df.sample(5)
# Out:
# Data loaded: 13,288,920 rows and 13 columns
#                 id           valid_time  latitude  longitude        tp  \
# 4614694    4614695  2018-05-07 17:00:00     50.00      -2.75  0.000000
# 11661644  11661645  2018-11-17 07:00:00     56.25      -4.50  0.000007
# 10065540  10065541  2018-10-04 11:00:00     57.75       2.00  0.000000
# 9867429    9867430  2018-09-29 00:00:00     53.75      -8.00  0.000000
# 2713978    2713979  2018-03-16 13:00:00     58.75      -2.00  0.000056
#
#                 u10       v10          sp       u100       v100       tcc  \
# 4614694    0.422897 -1.128342  101477.125  -0.582809  -0.239777  0.000000
# 11661644  -4.839416 -0.319321   99037.190  -8.124847  -0.290573  0.996246
# 10065540   8.723419  6.990631  101337.810  12.268143   9.180862  0.220734
# 9867429    1.102234  0.052383  102433.750   1.109055  -0.377686  0.532806
# 2713978  -14.051880  9.378448  101463.060 -16.914536  11.411743  1.000000
#
#           ptype        t2m
# 4614694     0.0  286.04297
# 11661644    1.0  278.70483
# 10065540    1.0  285.34520
# 9867429     0.0  278.80933
# 2713978     1.0  277.01930

# %% [markdown]
# ## 2. Missing Values and Duplicates
# Identify if there are any missing values or duplicates in the dataset as these could effect analysis

# %%
# Check for missing values
missing_values = train_df.isnull().sum()
missing_values = missing_values[missing_values > 0]

if missing_values.empty:
    print("No missing values in any column.")
else:
    print("Missing values found:")
    print(missing_values)

# Check for duplicates
duplicate_rows = train_df.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_rows}")
# Out:
# No missing values in any column.
# Number of duplicate rows: 0

# %% [markdown]
# ## 3. Dataset Feature Descriptions
#
# id: Observation Identifier (Not Needed)
# valid_time: Timestamp of the observation (could convert to datetime)
# latitude: Geospatial location
# longitude: Geospatial location
# tp: Total precipitation (metres)
# u10: Wind u components at 10m height positive = eastward, negative = westward
# v10: Wind v components at 10m height positive = northward, negative = southward
# u100: Same as u10 but at 100m height
# v100: Same as v10 but at 100m height
# sp: Surface pressure (Pa)
# tcc: Total cloud cover (0 = clear, 1 = full cloud)
# ptype: Precipitation type (categorical)
# t2m: Temperature at 2 metres (in Kelvin — convert to Celsius?)

# %% [markdown]
# ## 4. Simplify and Encode the feature ptype
#
# Precipitation Type Simplification and One-Hot Encoding
# The ptype column contains multiple weather conditions, but some are extremely rare. We grouped them into a few meaningful categories to reduce noise:
# 0: No precipitation
# 1: Regular rainfall
# 2 - 11: Other

# %%
# Define grouping function
def simplify_ptype(ptype):
    if ptype == 0:
        return 'none'
    elif ptype == 1:
        return 'rain'
    else:
        return 'other'

# Apply grouping
train_df['ptype_grouped'] = train_df['ptype'].apply(simplify_ptype)

# One-hot encode
ptype_dummies = pd.get_dummies(train_df['ptype_grouped'], prefix='ptype')
train_df = pd.concat([train_df, ptype_dummies], axis=1)

# %% [markdown]
# ## 5. Convert Temperature from Kelvin to Celsius
# Temperature Conversion
# The t2m variable represents temperature in Kelvin, which is not ideal for interpretation or modelling. It will be converted to Celsius, which is more intuitive for most people and machine learning models.
#
# ### I cannot see any client for this assignment and the predictions.csv file shows Kelvin for the temperature so we can keep it as Kelvin. Either way is fine.

# %%
train_df['t2m_C'] = train_df['t2m'] - 273.15

# %% [markdown]
# ## 6. Drop the ID Feature
# Removing the id Column:
# The id column is a unique identifier for each row and does not carry any predictive information so it will be removed.

# %%
# Drop the 'id' column
train_df.drop(columns=['id'], inplace=True)

# Confirm removal
print("id column removed.")
# Out:
# id column removed.

# %% [markdown]
# ## 7. Create Time-Based Features
# Creating Time-Based Features from valid_time
# The valid_time column contains timestamp information. This will be converted to datetime format and extract useful features like:
# hour: Hour of the day (0–23)
# month: Month of the year (1–12)
# dayofweek: Day of the week (0 = Monday, 6 = Sunday)
#
# These features may help capture daily and seasonal weather patterns.
#
# ### We could remove the dayofweek here, it isn't needed

# %%
# Convert 'valid_time' to datetime format
train_df['valid_time'] = pd.to_datetime(train_df['valid_time'])

# Extract time-based features
train_df['hour'] = train_df['valid_time'].dt.hour
train_df['month'] = train_df['valid_time'].dt.month
train_df['dayofweek'] = train_df['valid_time'].dt.dayofweek

# Display some examples
train_df[['valid_time', 'hour', 'month', 'dayofweek']].sample(10)
# Out:
#                   valid_time  hour  month  dayofweek
# 2427222  2018-03-08 16:00:00    16      3          3
# 5850147  2018-06-10 16:00:00    16      6          6
# 3864974  2018-04-17 03:00:00     3      4          1
# 10781454 2018-10-24 03:00:00     3     10          2
# 464761   2018-01-13 18:00:00    18      1          5
# 10970289 2018-10-29 07:00:00     7     10          0
# 6772963  2018-07-06 00:00:00     0      7          4
# 7636443  2018-07-29 17:00:00    17      7          6
# 420322   2018-01-12 13:00:00    13      1          4
# 3445094  2018-04-05 14:00:00    14      4          3

# %% [markdown]
# ## 8. Create Wind Speed Features
#
# Calculating Wind Speed from Wind Components. The wind is represented by two components:
#
# u = east–west (positive = eastward, negative = westward)
# v = north–south (positive = northward)
#
# To simplify these into one feature, we calculate wind speed using the formula:
# wind speed = sqrt(u2 + v2)
#
# ### This can be done for both 10m and 100m wind levels or we could just do it for one of them and drop the other.

# %%
# Calculate wind speed at 10m and 100m
train_df['wind10_speed'] = np.sqrt(train_df['u10']**2 + train_df['v10']**2)
train_df['wind100_speed'] = np.sqrt(train_df['u100']**2 + train_df['v100']**2)

# Display a few rows to check
train_df[['u10', 'v10', 'wind10_speed', 'u100', 'v100', 'wind100_speed']].head()
# Out:
#         u10       v10  wind10_speed      u100      v100  wind100_speed
# 0  1.405868 -1.367767      1.961442  1.516388 -1.468002       2.110560
# 1  2.151962 -1.555267      2.655146  2.239044 -1.634994       2.772458
# 2  2.691025 -1.585541      3.123388  2.783966 -1.686752       3.255088
# 3  2.850204 -1.714447      3.326108  2.971466 -1.854721       3.502799
# 4  3.299423 -1.867767      3.791405  3.455841 -2.001205       3.993452

# %% [markdown]
# ## 9. Wind Direction
#
# Calculating Wind Direction
#
# In addition to wind speed, we can calculate wind direction from the u and v components of wind.
#
# This will show where the wind is coming from, measured in degrees (0° = north, 90° = east, etc.)
# Wind direction may influence temperature, depending on regional wind patterns (e.g., warm air from the south, cold air from the north)
#
# What will be calculated:
#
# wind10_dir: Wind direction at 10 metres
# wind100_dir: Wind direction at 100 metres
#
# It will also convert the direction into sine and cosine components to handle the circular nature of angles (so the model understands that 0° and 360° are essentially the same).
#
# ### Again we can drop one of these remove the u100 and v100 features to try and save processing speed

# %%
# Wind direction (in degrees), where 0 = north, 90 = east, etc.
train_df['wind10_dir'] = (np.arctan2(train_df['u10'], train_df['v10']) * (180 / np.pi)) % 360
train_df['wind100_dir'] = (np.arctan2(train_df['u100'], train_df['v100']) * (180 / np.pi)) % 360

# Convert to radians for sine/cosine encoding
train_df['wind10_dir_rad'] = np.radians(train_df['wind10_dir'])

# Sine and cosine components
train_df['wind10_dir_sin'] = np.sin(train_df['wind10_dir_rad'])
train_df['wind10_dir_cos'] = np.cos(train_df['wind10_dir_rad'])

# Repeat for 100m wind in case it's useful
train_df['wind100_dir_rad'] = np.radians(train_df['wind100_dir'])
train_df['wind100_dir_sin'] = np.sin(train_df['wind100_dir_rad'])
train_df['wind100_dir_cos'] = np.cos(train_df['wind100_dir_rad'])

# Check the dataset
train_df[['u10', 'v10', 'wind10_dir', 'wind10_dir_sin', 'wind10_dir_cos', 'wind100_dir']].sample(10)
# Out:
#                u10       v10  wind10_dir  wind10_dir_sin  wind10_dir_cos  \
# 650966    4.760696  2.263199   64.573941        0.903140        0.429346
# 11172334  0.876099  9.998276    5.007750        0.087290        0.996183
# 2897083   4.754364 -0.196503   92.366746        0.999147       -0.041296
# 2441940   1.420212  1.560120   42.312297        0.673171        0.739487
# 2433388  -2.655533  6.413925  337.509165       -0.382536        0.923941
# 9029975   3.615951 -3.778641  136.260367        0.691382       -0.722489
# 8767116   8.618744 -1.022278   96.764306        0.993039       -0.117785
# 5874411   3.928131 -3.955841  135.201378        0.704617       -0.709588
# 11396795  0.264923  5.761810    2.632557        0.045931        0.998945
# 4746931  -5.028229  6.398361  321.837541       -0.617893        0.786262
#
#           wind100_dir
# 650966      66.026277
# 11172334     5.211576
# 2897083     93.497193
# 2441940     62.648292
# 2433388    338.113076
# 9029975    138.324172
# 8767116     97.117417
# 5874411    135.674297
# 11396795     4.498919
# 4746931    326.753923

# %% [markdown]
# ## 10. Scaling Numerical Features for Modelling
#
# It is planned to use linear regression and neural networks, so, it is important to scale our numerical features. These models are sensitive to differences in magnitude between features.
#
# For example:
#
# sp: (surface pressure) is around 100,000 Pa
# tp: (precipitation) is usually < 0.01
# tcc:  (cloud cover) already ranges between 0 and 1
#
# If these features arenot scaled, models may unintentionally give more weight to features with larger values, even if they are not more important.
#
# Standard Scaling can be used, which transforms features to have:
# A mean of 0
# A standard deviation of 1
#
# The following will not scaled:
#
# tcc: Already normalised between 0–1
# One-hot encoded variables (e.g., precipitation type, day of week)
# Wind direction sine/cosine: Already between -1 and 1
#
# These will be scaled:
# Surface pressure
# Wind speed
# Precipitation
# Time-based features (e.g., hour, month), optional, not sure but may be helpful
#
# ### Not sure if we need some of these features but I have normalised them anyway. We can drop the wind100_speed and dayofweek features from here as well

# %%
# List of features to scale
features_to_scale = [
    # Total precipitation
    'tp',
    # Surface pressure
    'sp',
    # Wind speed at 10m
    'wind10_speed',
    # Wind speed at 100m
    'wind100_speed',
    # Hour of day
    'hour',
    # Month of year
    'month',
    # Day of week
    'dayofweek',     
]

# Create a copy of the dataframe to preserve original features
train_scaled = train_df.copy()

# Initialise the scaler
scaler = StandardScaler()

# Apply scaling to selected features
train_scaled[features_to_scale] = scaler.fit_transform(train_scaled[features_to_scale])

# Display scaled values to confirm
train_scaled[features_to_scale].head()
# Out:
#          tp        sp  wind10_speed  wind100_speed      hour     month  \
# 0 -0.346954 -1.455549     -1.203479      -1.440209 -1.661325 -1.602745
# 1 -0.306935 -1.484714     -1.009811      -1.289457 -1.661325 -1.602745
# 2 -0.302488 -1.489575     -0.879087      -1.179535 -1.661325 -1.602745
# 3 -0.299524 -1.490790     -0.822491      -1.123118 -1.661325 -1.602745
# 4 -0.311381 -1.485929     -0.692590      -1.011368 -1.661325 -1.602745
#
#    dayofweek
# 0  -1.493348
# 1  -1.493348
# 2  -1.493348
# 3  -1.493348
# 4  -1.493348

# %% [markdown]
# ## 11. Cyclical Time Feature Encoding
#
# Encoding Time Features as Cyclical Values
#
# Time-based features like hour, month, and dayofweek are cyclical, they repeat in a loop:
#
# Hour 23 is followed by hour 0 (midnight)
# December (12) is followed by January (1)
# Sunday (6) is followed by Monday (0)
#
# Treating these as plain numbers would mislead the model into thinking that the highest values are "further away" from the lowest, when in fact they are neighbours.
#
# To handle this, we transform each feature using sine and cosine. This places the values on a circle, helping the model understand the cyclical nature of time.
#
# ### I have kept these explanations in for our write up if we need it. Again no need for day of the week

# %%
# Encode 'hour' as cyclical
train_scaled['hour_sin'] = np.sin(2 * np.pi * train_scaled['hour'] / 24)
train_scaled['hour_cos'] = np.cos(2 * np.pi * train_scaled['hour'] / 24)

# Encode 'month' as cyclical
train_scaled['month_sin'] = np.sin(2 * np.pi * train_scaled['month'] / 12)
train_scaled['month_cos'] = np.cos(2 * np.pi * train_scaled['month'] / 12)

# Encode 'dayofweek' as cyclical (0=Monday, 6=Sunday)
train_scaled['dow_sin'] = np.sin(2 * np.pi * train_scaled['dayofweek'] / 7)
train_scaled['dow_cos'] = np.cos(2 * np.pi * train_scaled['dayofweek'] / 7)

# Check a few rows
train_scaled[['hour', 'hour_sin', 'hour_cos', 'month', 'month_sin', 'month_cos']].sample(10)
# Out:
#               hour  hour_sin  hour_cos     month  month_sin  month_cos
# 1211869  -0.794547 -0.206515  0.978443 -1.312710  -0.634478   0.772941
# 10480680  1.227936  0.315964  0.948771  1.007576   0.503431   0.864035
# 2384993   0.072232  0.018909  0.999821 -1.022674  -0.510246   0.860029
# 10817435 -1.372399 -0.351613  0.936146  1.007576   0.503431   0.864035
# 4353465   0.216695  0.056700  0.998391 -0.732638  -0.374269   0.927320
# 11393528  1.516862  0.386758  0.922181  1.297612   0.628348   0.777932
# 2352092   0.361158  0.094410  0.995533 -1.022674  -0.510246   0.860029
# 10445198  1.372399  0.351613  0.936146  1.007576   0.503431   0.864035
# 4455680  -0.361158 -0.094410  0.995533 -0.442602  -0.229677   0.973267
# 10097574 -0.505621 -0.131985  0.991252  1.007576   0.503431   0.864035

# %% [markdown]
# ## I have deleted the rolling three hour feature and the lag feature of 1 hour as these seem unnecessary now

# %% [markdown]
# ## 12. Feature Selection
#
# Selecting Input Features and Target Variable
#
# Define:
#
# y: the target variable, temperature in Celsius (t2m_C)
# X: the input features we want the model to use to make predictions
#
# This includes weather features, time encodings, wind features, and one-hot precipitation types.

# %%
# Define the target
y = train_scaled['t2m_C']

# Define input features for the model
feature_cols = [
    'tp', 'sp', 'wind10_speed', 'wind100_speed',
    'hour_sin', 'hour_cos',
    'month_sin', 'month_cos',
    'wind10_dir_sin', 'wind10_dir_cos',
    'ptype_none', 'ptype_rain', 'ptype_other',
]

# Create feature matrix
X = train_scaled[feature_cols]

print(f"Features and target selected. Feature matrix shape: {X.shape}")
# Out:
# Features and target selected. Feature matrix shape: (13288920, 13)

# %% [markdown]
# ## Dataset with new features:

# %%
# Display 10 random rows from the processed dataset
train_scaled.sample(5, random_state=42)
# Out:
#                 id          valid_time  latitude  longitude        tp  \
# 4813198    4813199 2018-05-13 04:00:00     51.25      -7.25 -0.358812
# 11648609  11648610 2018-11-16 22:00:00     52.50      -3.75 -0.343990
# 1226538    1226539 2018-02-03 16:00:00     54.25      -2.25  0.171814
# 9860476    9860477 2018-09-28 19:00:00     50.00      -3.75 -0.358812
# 2016645    2016646 2018-02-25 09:00:00     55.75      -3.25 -0.358812
#
#                u10       v10        sp      u100      v100  ...  \
# 4813198   5.886337 -0.648453  0.562722  6.440597 -0.707596  ...
# 11648609 -4.333618  1.897888 -0.802600 -7.078690  3.492432  ...
# 1226538  -1.242538 -1.477005 -2.438537 -1.713867 -2.030670  ...
# 9860476  -7.468582 -4.135788  1.452785 -9.300003 -4.978210  ...
# 2016645  -2.917770  2.137604 -0.592904 -4.929230  4.259506  ...
#
#           wind10_dir_cos  wind100_dir_rad  wind100_dir_sin wind100_dir_cos  \
# 4813198        -0.109500         1.680222         0.994019       -0.109208
# 11648609        0.401161         5.170721        -0.896792        0.442453
# 1226538        -0.765232         3.842588        -0.644978       -0.764201
# 9860476        -0.484441         4.220909        -0.881635       -0.471932
# 2016645         0.590987         5.425031        -0.756637        0.653835
#
#           hour_sin  hour_cos  month_sin  month_cos   dow_sin   dow_cos
# 4813198  -0.279864  0.960040  -0.229677   0.973267  0.975237  0.221161
# 11648609  0.386758  0.922181   0.628348   0.777932  0.436512  0.899698
# 1226538   0.169371  0.985552  -0.634478   0.772941  0.783175  0.621802
# 9860476   0.279864  0.960040   0.366927   0.930250  0.436512  0.899698
# 2016645  -0.094410  0.995533  -0.634478   0.772941  0.975237  0.221161
#
# [5 rows x 37 columns]

# %% [markdown]
# ## 13. Removal of Unwanted Features
#
# We can use this code to remove any features we don't want
#
# In the code the features dow_sin and dow_cos (days of week) have been removed, we can just add further features to drop here

# %%
# Define for removal
features_to_drop = ['dow_sin', 'dow_cos']

# Drop the features
cleaned_df = train_scaled.drop(columns=features_to_drop)

# Display first 5 rows of the cleaned dataset
print("Preview of cleaned dataset:")
display(cleaned_df.head())

# Save the head (first 5 rows) to a CSV file
head_df = cleaned_df.head()
head_df.to_csv("cleaned_dataset_head.csv", index=False)

print("Saved 'cleaned_dataset_head.csv'")
# Out:
# Preview of cleaned dataset:
#    id valid_time  latitude  longitude        tp       u10       v10        sp  \
# 0   1 2018-01-01      59.0      -8.00 -0.346954  1.405868 -1.367767 -1.455549
# 1   2 2018-01-01      59.0      -7.75 -0.306935  2.151962 -1.555267 -1.484714
# 2   3 2018-01-01      59.0      -7.50 -0.302488  2.691025 -1.585541 -1.489575
# 3   4 2018-01-01      59.0      -7.25 -0.299524  2.850204 -1.714447 -1.490790
# 4   5 2018-01-01      59.0      -7.00 -0.311381  3.299423 -1.867767 -1.485929
#
#        u100      v100  ...  wind10_dir_rad  wind10_dir_sin  wind10_dir_cos  \
# 0  1.516388 -1.468002  ...        2.342458        0.716753       -0.697328
# 1  2.239044 -1.634994  ...        2.196609        0.810487       -0.585756
# 2  2.783966 -1.686752  ...        2.103234        0.861572       -0.507635
# 3  2.971466 -1.854721  ...        2.112331        0.856919       -0.515451
# 4  3.455841 -2.001205  ...        2.085908        0.870238       -0.492632
#
#   wind100_dir_rad  wind100_dir_sin  wind100_dir_cos  hour_sin  hour_cos  \
# 0        2.339983         0.718477        -0.695551  -0.42135  0.906898
# 1        2.201517         0.807602        -0.589727  -0.42135  0.906898
# 2        2.115529         0.855266        -0.518189  -0.42135  0.906898
# 3        2.128804         0.848312        -0.529497  -0.42135  0.906898
# 4        2.095691         0.865377        -0.501122  -0.42135  0.906898
#
#    month_sin  month_cos
# 0  -0.744106   0.668062
# 1  -0.744106   0.668062
# 2  -0.744106   0.668062
# 3  -0.744106   0.668062
# 4  -0.744106   0.668062
#
# [5 rows x 35 columns]
# Saved 'cleaned_dataset_head.csv'

# %% [markdown]
# ## 13: Feed Forward Neural Net (Multi-Layer Perception)

# %%
# Import libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Set seeds for reproducibility
np.random.seed(99)
tf.random.set_seed(99)

# Take a 10% sample of the cleaned dataset
sampled_df = cleaned_df.sample(frac=0.10, random_state=99)

# Split into 80% for training and 20% for validation/testing
train_subset, validation_subset = train_test_split(
    sampled_df, test_size=0.2, random_state=99
)

# Use only the selected input features
X_train = train_subset[feature_cols]
y_train = train_subset['t2m_C']

X_val = validation_subset[feature_cols]
y_val_actual = validation_subset['t2m_C']

# Ensure only numeric features are used
X_train = X_train.select_dtypes(include=[np.number])
X_val = X_val.select_dtypes(include=[np.number])

# Scale the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)

# Build neural network
model = keras.Sequential([
    keras.Input(shape=(X_train_scaled.shape[1],)),
    layers.Dense(64, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(1)
])

# Compile the model
model.compile(
    optimizer='adam',
    loss='mean_squared_error',
    metrics=['mean_absolute_error']
)

# Add early stopping
early_stop = keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

# Train model
history = model.fit(
    X_train_scaled, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=64,
    callbacks=[early_stop],
    verbose=1
)

# Predict on validation subset
y_val_pred = model.predict(X_val_scaled).flatten()

# Evaluate predictions
rmse = np.sqrt(mean_squared_error(y_val_actual, y_val_pred))
mae = mean_absolute_error(y_val_actual, y_val_pred)

print("\nNeural Network Evaluation on Validation Set:")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
# Out:
# Epoch 1/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 53s 4ms/step - loss: 8.6124 - mean_absolute_error: 2.0775 - val_loss: 4.6204 - val_mean_absolute_error: 1.6426
# Epoch 2/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 52s 4ms/step - loss: 4.5385 - mean_absolute_error: 1.6262 - val_loss: 4.4245 - val_mean_absolute_error: 1.6023
# Epoch 3/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 49s 4ms/step - loss: 4.3876 - mean_absolute_error: 1.5940 - val_loss: 4.3156 - val_mean_absolute_error: 1.5794
# Epoch 4/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 50s 4ms/step - loss: 4.3054 - mean_absolute_error: 1.5763 - val_loss: 4.2572 - val_mean_absolute_error: 1.5679
# Epoch 5/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 52s 4ms/step - loss: 4.2487 - mean_absolute_error: 1.5642 - val_loss: 4.2112 - val_mean_absolute_error: 1.5579
# Epoch 6/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 49s 4ms/step - loss: 4.2023 - mean_absolute_error: 1.5544 - val_loss: 4.1753 - val_mean_absolute_error: 1.5502
# Epoch 7/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 49s 4ms/step - loss: 4.1657 - mean_absolute_error: 1.5470 - val_loss: 4.1416 - val_mean_absolute_error: 1.5430
# Epoch 8/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 50s 4ms/step - loss: 4.1326 - mean_absolute_error: 1.5407 - val_loss: 4.1096 - val_mean_absolute_error: 1.5368
# Epoch 9/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 50s 4ms/step - loss: 4.1006 - mean_absolute_error: 1.5343 - val_loss: 4.0873 - val_mean_absolute_error: 1.5318
# Epoch 10/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 53s 4ms/step - loss: 4.0745 - mean_absolute_error: 1.5289 - val_loss: 4.0683 - val_mean_absolute_error: 1.5277
# Epoch 11/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 52s 4ms/step - loss: 4.0523 - mean_absolute_error: 1.5239 - val_loss: 4.0449 - val_mean_absolute_error: 1.5217
# Epoch 12/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 49s 4ms/step - loss: 4.0340 - mean_absolute_error: 1.5195 - val_loss: 4.0236 - val_mean_absolute_error: 1.5167
# Epoch 13/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 50s 4ms/step - loss: 4.0168 - mean_absolute_error: 1.5157 - val_loss: 4.0143 - val_mean_absolute_error: 1.5130
# Epoch 14/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 50s 4ms/step - loss: 4.0016 - mean_absolute_error: 1.5121 - val_loss: 4.0017 - val_mean_absolute_error: 1.5101
# Epoch 15/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 51s 4ms/step - loss: 3.9869 - mean_absolute_error: 1.5086 - val_loss: 3.9855 - val_mean_absolute_error: 1.5064
# Epoch 16/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 50s 4ms/step - loss: 3.9726 - mean_absolute_error: 1.5052 - val_loss: 3.9742 - val_mean_absolute_error: 1.5027
# Epoch 17/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 49s 4ms/step - loss: 3.9608 - mean_absolute_error: 1.5023 - val_loss: 3.9685 - val_mean_absolute_error: 1.5016
# Epoch 18/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 51s 4ms/step - loss: 3.9502 - mean_absolute_error: 1.5002 - val_loss: 3.9566 - val_mean_absolute_error: 1.4993
# Epoch 19/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 50s 4ms/step - loss: 3.9414 - mean_absolute_error: 1.4983 - val_loss: 3.9450 - val_mean_absolute_error: 1.4971
# Epoch 20/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 51s 4ms/step - loss: 3.9329 - mean_absolute_error: 1.4966 - val_loss: 3.9347 - val_mean_absolute_error: 1.4948
# Epoch 21/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 51s 4ms/step - loss: 3.9253 - mean_absolute_error: 1.4951 - val_loss: 3.9271 - val_mean_absolute_error: 1.4931
# Epoch 22/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 50s 4ms/step - loss: 3.9193 - mean_absolute_error: 1.4939 - val_loss: 3.9206 - val_mean_absolute_error: 1.4917
# Epoch 23/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 52s 4ms/step - loss: 3.9120 - mean_absolute_error: 1.4926 - val_loss: 3.9168 - val_mean_absolute_error: 1.4911
# Epoch 24/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 50s 4ms/step - loss: 3.9057 - mean_absolute_error: 1.4914 - val_loss: 3.9128 - val_mean_absolute_error: 1.4904
# Epoch 25/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 46s 3ms/step - loss: 3.9007 - mean_absolute_error: 1.4903 - val_loss: 3.9039 - val_mean_absolute_error: 1.4884
# Epoch 26/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 52s 4ms/step - loss: 3.8956 - mean_absolute_error: 1.4893 - val_loss: 3.9010 - val_mean_absolute_error: 1.4876
# Epoch 27/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 54s 4ms/step - loss: 3.8902 - mean_absolute_error: 1.4881 - val_loss: 3.8921 - val_mean_absolute_error: 1.4860
# Epoch 28/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 53s 4ms/step - loss: 3.8845 - mean_absolute_error: 1.4871 - val_loss: 3.8910 - val_mean_absolute_error: 1.4856
# Epoch 29/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 51s 4ms/step - loss: 3.8776 - mean_absolute_error: 1.4856 - val_loss: 3.8870 - val_mean_absolute_error: 1.4850
# Epoch 30/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 51s 4ms/step - loss: 3.8719 - mean_absolute_error: 1.4843 - val_loss: 3.8782 - val_mean_absolute_error: 1.4829
# Epoch 31/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 51s 4ms/step - loss: 3.8661 - mean_absolute_error: 1.4831 - val_loss: 3.8754 - val_mean_absolute_error: 1.4824
# Epoch 32/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 53s 4ms/step - loss: 3.8598 - mean_absolute_error: 1.4818 - val_loss: 3.8643 - val_mean_absolute_error: 1.4799
# Epoch 33/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 52s 4ms/step - loss: 3.8547 - mean_absolute_error: 1.4807 - val_loss: 3.8577 - val_mean_absolute_error: 1.4791
# Epoch 34/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 53s 4ms/step - loss: 3.8495 - mean_absolute_error: 1.4796 - val_loss: 3.8543 - val_mean_absolute_error: 1.4785
# Epoch 35/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 54s 4ms/step - loss: 3.8445 - mean_absolute_error: 1.4786 - val_loss: 3.8432 - val_mean_absolute_error: 1.4764
# Epoch 36/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 54s 4ms/step - loss: 3.8396 - mean_absolute_error: 1.4777 - val_loss: 3.8412 - val_mean_absolute_error: 1.4766
# Epoch 37/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 52s 4ms/step - loss: 3.8331 - mean_absolute_error: 1.4767 - val_loss: 3.8344 - val_mean_absolute_error: 1.4750
# Epoch 38/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 54s 4ms/step - loss: 3.8290 - mean_absolute_error: 1.4759 - val_loss: 3.8320 - val_mean_absolute_error: 1.4752
# Epoch 39/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 53s 4ms/step - loss: 3.8253 - mean_absolute_error: 1.4750 - val_loss: 3.8279 - val_mean_absolute_error: 1.4733
# Epoch 40/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 56s 4ms/step - loss: 3.8206 - mean_absolute_error: 1.4742 - val_loss: 3.8246 - val_mean_absolute_error: 1.4734
# Epoch 41/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 64s 5ms/step - loss: 3.8155 - mean_absolute_error: 1.4733 - val_loss: 3.8181 - val_mean_absolute_error: 1.4718
# Epoch 42/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 59s 4ms/step - loss: 3.8119 - mean_absolute_error: 1.4726 - val_loss: 3.8151 - val_mean_absolute_error: 1.4715
# Epoch 43/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 61s 5ms/step - loss: 3.8074 - mean_absolute_error: 1.4717 - val_loss: 3.8118 - val_mean_absolute_error: 1.4710
# Epoch 44/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 59s 4ms/step - loss: 3.8037 - mean_absolute_error: 1.4710 - val_loss: 3.8061 - val_mean_absolute_error: 1.4693
# Epoch 45/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 57s 4ms/step - loss: 3.7997 - mean_absolute_error: 1.4705 - val_loss: 3.8047 - val_mean_absolute_error: 1.4697
# Epoch 46/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 60s 5ms/step - loss: 3.7952 - mean_absolute_error: 1.4695 - val_loss: 3.8012 - val_mean_absolute_error: 1.4688
# Epoch 47/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 59s 4ms/step - loss: 3.7916 - mean_absolute_error: 1.4689 - val_loss: 3.7912 - val_mean_absolute_error: 1.4669
# Epoch 48/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 60s 4ms/step - loss: 3.7875 - mean_absolute_error: 1.4683 - val_loss: 3.7959 - val_mean_absolute_error: 1.4680
# Epoch 49/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 56s 4ms/step - loss: 3.7834 - mean_absolute_error: 1.4675 - val_loss: 3.7833 - val_mean_absolute_error: 1.4656
# Epoch 50/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 54s 4ms/step - loss: 3.7798 - mean_absolute_error: 1.4669 - val_loss: 3.7800 - val_mean_absolute_error: 1.4646
# Epoch 51/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 55s 4ms/step - loss: 3.7763 - mean_absolute_error: 1.4660 - val_loss: 3.7804 - val_mean_absolute_error: 1.4650
# Epoch 52/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 53s 4ms/step - loss: 3.7718 - mean_absolute_error: 1.4651 - val_loss: 3.7735 - val_mean_absolute_error: 1.4640
# Epoch 53/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 53s 4ms/step - loss: 3.7682 - mean_absolute_error: 1.4642 - val_loss: 3.7654 - val_mean_absolute_error: 1.4617
# Epoch 54/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 48s 4ms/step - loss: 3.7660 - mean_absolute_error: 1.4638 - val_loss: 3.7628 - val_mean_absolute_error: 1.4613
# Epoch 55/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 54s 4ms/step - loss: 3.7626 - mean_absolute_error: 1.4632 - val_loss: 3.7625 - val_mean_absolute_error: 1.4613
# Epoch 56/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 58s 4ms/step - loss: 3.7597 - mean_absolute_error: 1.4625 - val_loss: 3.7549 - val_mean_absolute_error: 1.4598
# Epoch 57/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 53s 4ms/step - loss: 3.7571 - mean_absolute_error: 1.4619 - val_loss: 3.7547 - val_mean_absolute_error: 1.4591
# Epoch 58/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 56s 4ms/step - loss: 3.7544 - mean_absolute_error: 1.4612 - val_loss: 3.7563 - val_mean_absolute_error: 1.4598
# Epoch 59/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 56s 4ms/step - loss: 3.7515 - mean_absolute_error: 1.4606 - val_loss: 3.7540 - val_mean_absolute_error: 1.4594
# Epoch 60/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 55s 4ms/step - loss: 3.7484 - mean_absolute_error: 1.4600 - val_loss: 3.7458 - val_mean_absolute_error: 1.4577
# Epoch 61/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 58s 4ms/step - loss: 3.7448 - mean_absolute_error: 1.4592 - val_loss: 3.7445 - val_mean_absolute_error: 1.4570
# Epoch 62/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 53s 4ms/step - loss: 3.7422 - mean_absolute_error: 1.4587 - val_loss: 3.7363 - val_mean_absolute_error: 1.4554
# Epoch 63/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 58s 4ms/step - loss: 3.7392 - mean_absolute_error: 1.4579 - val_loss: 3.7356 - val_mean_absolute_error: 1.4547
# Epoch 64/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 50s 4ms/step - loss: 3.7360 - mean_absolute_error: 1.4573 - val_loss: 3.7357 - val_mean_absolute_error: 1.4544
# Epoch 65/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 56s 4ms/step - loss: 3.7341 - mean_absolute_error: 1.4567 - val_loss: 3.7339 - val_mean_absolute_error: 1.4546
# Epoch 66/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 57s 4ms/step - loss: 3.7316 - mean_absolute_error: 1.4561 - val_loss: 3.7325 - val_mean_absolute_error: 1.4542
# Epoch 67/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 56s 4ms/step - loss: 3.7290 - mean_absolute_error: 1.4555 - val_loss: 3.7293 - val_mean_absolute_error: 1.4534
# Epoch 68/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 57s 4ms/step - loss: 3.7261 - mean_absolute_error: 1.4549 - val_loss: 3.7295 - val_mean_absolute_error: 1.4535
# Epoch 69/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 57s 4ms/step - loss: 3.7246 - mean_absolute_error: 1.4545 - val_loss: 3.7298 - val_mean_absolute_error: 1.4536
# Epoch 70/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 54s 4ms/step - loss: 3.7219 - mean_absolute_error: 1.4540 - val_loss: 3.7281 - val_mean_absolute_error: 1.4534
# Epoch 71/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 45s 3ms/step - loss: 3.7209 - mean_absolute_error: 1.4537 - val_loss: 3.7226 - val_mean_absolute_error: 1.4517
# Epoch 72/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 46s 3ms/step - loss: 3.7180 - mean_absolute_error: 1.4530 - val_loss: 3.7232 - val_mean_absolute_error: 1.4521
# Epoch 73/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 46s 3ms/step - loss: 3.7161 - mean_absolute_error: 1.4525 - val_loss: 3.7200 - val_mean_absolute_error: 1.4509
# Epoch 74/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 48s 4ms/step - loss: 3.7139 - mean_absolute_error: 1.4519 - val_loss: 3.7155 - val_mean_absolute_error: 1.4501
# Epoch 75/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 44s 3ms/step - loss: 3.7115 - mean_absolute_error: 1.4513 - val_loss: 3.7123 - val_mean_absolute_error: 1.4493
# Epoch 76/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 45s 3ms/step - loss: 3.7096 - mean_absolute_error: 1.4508 - val_loss: 3.7159 - val_mean_absolute_error: 1.4502
# Epoch 77/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 46s 3ms/step - loss: 3.7078 - mean_absolute_error: 1.4505 - val_loss: 3.7111 - val_mean_absolute_error: 1.4489
# Epoch 78/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 45s 3ms/step - loss: 3.7050 - mean_absolute_error: 1.4499 - val_loss: 3.7082 - val_mean_absolute_error: 1.4482
# Epoch 79/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - loss: 3.7040 - mean_absolute_error: 1.4495 - val_loss: 3.7042 - val_mean_absolute_error: 1.4475
# Epoch 80/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 56s 4ms/step - loss: 3.7024 - mean_absolute_error: 1.4491 - val_loss: 3.7059 - val_mean_absolute_error: 1.4476
# Epoch 81/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 58s 4ms/step - loss: 3.7006 - mean_absolute_error: 1.4487 - val_loss: 3.7029 - val_mean_absolute_error: 1.4474
# Epoch 82/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 59s 4ms/step - loss: 3.6990 - mean_absolute_error: 1.4484 - val_loss: 3.6996 - val_mean_absolute_error: 1.4464
# Epoch 83/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 59s 4ms/step - loss: 3.6972 - mean_absolute_error: 1.4480 - val_loss: 3.6977 - val_mean_absolute_error: 1.4461
# Epoch 84/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 59s 4ms/step - loss: 3.6956 - mean_absolute_error: 1.4476 - val_loss: 3.6957 - val_mean_absolute_error: 1.4460
# Epoch 85/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 60s 4ms/step - loss: 3.6944 - mean_absolute_error: 1.4474 - val_loss: 3.6962 - val_mean_absolute_error: 1.4459
# Epoch 86/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 59s 4ms/step - loss: 3.6922 - mean_absolute_error: 1.4469 - val_loss: 3.6932 - val_mean_absolute_error: 1.4452
# Epoch 87/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 58s 4ms/step - loss: 3.6912 - mean_absolute_error: 1.4467 - val_loss: 3.6938 - val_mean_absolute_error: 1.4455
# Epoch 88/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 61s 5ms/step - loss: 3.6900 - mean_absolute_error: 1.4463 - val_loss: 3.6918 - val_mean_absolute_error: 1.4452
# Epoch 89/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 62s 5ms/step - loss: 3.6887 - mean_absolute_error: 1.4461 - val_loss: 3.6888 - val_mean_absolute_error: 1.4446
# Epoch 90/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 60s 4ms/step - loss: 3.6868 - mean_absolute_error: 1.4457 - val_loss: 3.6894 - val_mean_absolute_error: 1.4443
# Epoch 91/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 56s 4ms/step - loss: 3.6859 - mean_absolute_error: 1.4454 - val_loss: 3.6902 - val_mean_absolute_error: 1.4444
# Epoch 92/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 49s 4ms/step - loss: 3.6852 - mean_absolute_error: 1.4452 - val_loss: 3.6861 - val_mean_absolute_error: 1.4434
# Epoch 93/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 59s 4ms/step - loss: 3.6830 - mean_absolute_error: 1.4446 - val_loss: 3.6822 - val_mean_absolute_error: 1.4429
# Epoch 94/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 61s 5ms/step - loss: 3.6822 - mean_absolute_error: 1.4445 - val_loss: 3.6850 - val_mean_absolute_error: 1.4437
# Epoch 95/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 55s 4ms/step - loss: 3.6812 - mean_absolute_error: 1.4444 - val_loss: 3.6838 - val_mean_absolute_error: 1.4432
# Epoch 96/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 50s 4ms/step - loss: 3.6798 - mean_absolute_error: 1.4440 - val_loss: 3.6824 - val_mean_absolute_error: 1.4430
# Epoch 97/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 46s 3ms/step - loss: 3.6787 - mean_absolute_error: 1.4437 - val_loss: 3.6804 - val_mean_absolute_error: 1.4423
# Epoch 98/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 56s 4ms/step - loss: 3.6770 - mean_absolute_error: 1.4434 - val_loss: 3.6819 - val_mean_absolute_error: 1.4429
# Epoch 99/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 54s 4ms/step - loss: 3.6762 - mean_absolute_error: 1.4434 - val_loss: 3.6800 - val_mean_absolute_error: 1.4426
# Epoch 100/100
# 13289/13289 ━━━━━━━━━━━━━━━━━━━━ 54s 4ms/step - loss: 3.6752 - mean_absolute_error: 1.4431 - val_loss: 3.6796 - val_mean_absolute_error: 1.4424
# 8306/8306 ━━━━━━━━━━━━━━━━━━━━ 15s 2ms/step
#
# Neural Network Evaluation on Hold-Out Validation Set:
# Root Mean Squared Error (RMSE): 1.92
# Mean Absolute Error (MAE): 1.44

# %%
# Compare actual vs predicted temperature values
comparison_df = pd.DataFrame({
    'Actual': y_val_actual.values,
    'Predicted': y_val_pred
})

# View the first 20 rows
print("Sample of predicted vs actual temperatures:")
display(comparison_df.head(20))
# Out:
# Sample of predicted vs actual temperatures:
#       Actual  Predicted
# 0   13.19840  11.506401
# 1   14.49330  10.689627
# 2   14.51382  15.212631
# 3   14.61733  12.689357
# 4    4.91080   5.518839
# 5   17.66787  14.597844
# 6   14.66714  15.730021
# 7    5.66530   5.653523
# 8    5.60952   8.076424
# 9    5.88125   5.805490
# 10  17.38150  14.061771
# 11   4.51162   6.417341
# 12  13.39200  12.992420
# 13   3.41665   4.323606
# 14   6.90957   9.341197
# 15  15.67007  15.586067
# 16   9.36953   9.743983
# 17  17.09610  19.965303
# 18   6.71963   8.156955
# 19   1.22500  -1.883876

# %% [markdown]
# ## 14: Random Forest Model

# %%
# Set random seed for reproducibility
np.random.seed(99)

# Take a 10% sample of the dataset
sampled_df = cleaned_df.sample(frac=0.10, random_state=99)

# Split 10% sample into 80% train and 20% validation
train_subset, val_subset = train_test_split(sampled_df, test_size=0.2, random_state=99)

# Separate input features and target
X_train = train_subset[feature_cols]
y_train = train_subset['t2m_C']

X_val = val_subset[feature_cols]
y_val = val_subset['t2m_C']

# Not sure if this is needed
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)

# Create and train the Random Forest model
rf_model = RandomForestRegressor(
    # Number of trees
    n_estimators=25,
    # Reproducibility
    random_state=99, 
    n_jobs=-1 
)
rf_model.fit(X_train_scaled, y_train)

# Predict on validation set
y_pred = rf_model.predict(X_val_scaled)

# Evaluate
rmse = np.sqrt(mean_squared_error(y_val, y_pred))
mae = mean_absolute_error(y_val, y_pred)

print("\nRandom Forest Evaluation on Validation Set:")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
# Out:
# Random Forest Evaluation on Validation Set:
# Root Mean Squared Error (RMSE): 1.63
# Mean Absolute Error (MAE): 1.12

# %% [markdown]
# ## 15: SDG Regressor Model

# %%
# Set random seed
np.random.seed(99)

# Take a 10% sample of the cleaned dataset
sampled_df = cleaned_df.sample(frac=0.10, random_state=99)

# Split into training and validation subsets
train_subset, val_subset = train_test_split(sampled_df, test_size=0.2, random_state=99)

# Extract features and target
X_train = train_subset[feature_cols]
y_train = train_subset['t2m_C']

X_val = val_subset[feature_cols]
y_val = val_subset['t2m_C']

# Scale features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)

# Initialise and train the model
sgd_model = SGDRegressor(max_iter=1000, tol=1e-3, random_state=99)
sgd_model.fit(X_train_scaled, y_train)

# Predict on the validation set
y_pred = sgd_model.predict(X_val_scaled)

# Evaluate the model
rmse = np.sqrt(mean_squared_error(y_val, y_pred))
mae = mean_absolute_error(y_val, y_pred)

print("\nSGDRegressor Evaluation on Validation Set:")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
# Out:
#  SGDRegressor Evaluation on Validation Set:
# Root Mean Squared Error (RMSE): 3.15
# Mean Absolute Error (MAE): 2.46
